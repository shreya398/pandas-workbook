# %%
#Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import  files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-2ee3224e-25f7-439e-a455-f7da50caa0e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ee3224e-25f7-439e-a455-f7da50caa0e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Reading the data
df=pd.read_csv('AAPL.csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1     2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2     2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3     2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4     2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...          ...         ...         ...         ...         ...         ...
# 2006  2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007  2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008  2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009  2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010  2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume
# 0     75555200
# ...

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2012-01-03  58.485714  58.928570  58.428570  58.747143  50.765709  75555200
# 1  2012-01-04  58.571430  59.240002  58.468571  59.062859  51.038536  65005500
# 2  2012-01-05  59.278572  59.792858  58.952858  59.718571  51.605175  67817400
# 3  2012-01-06  59.967144  60.392857  59.888573  60.342857  52.144630  79573200
# 4  2012-01-09  60.785713  61.107143  60.192856  60.247143  52.061932  98506100

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2006  2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007  2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008  2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009  2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010  2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume
# 2006  24643000
# 2007  12119700
# 2008  23280300
# 2009  36566500
# 2010  36028600

# %%
df.shape
# Out:
# (2011, 7)

# %% [markdown]
# There are 2011 rows and 7 columns.

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#Descriptive stat
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2011.000000  2011.000000  2011.000000  2011.000000  2011.000000
# mean    126.707469   127.827594   125.580258   126.741235   119.505548
# std      50.483753    50.926301    50.124940    50.578369    52.438444
# min      55.424286    57.085712    55.014286    55.790001    48.921928
# 25%      85.882858    86.717858    85.056427    86.202145    75.056679
# 50%     113.050003   114.190002   111.870003   113.050003   105.222908
# 75%     165.190002   167.409996   163.424995   165.245002   160.047111
# max     291.119995   293.970001   288.119995   291.519989   289.522614
#
#              Volume
# count  2.011000e+03
# mean   5.949670e+07
# std    4.683856e+07
# min    1.136200e+07
# 25%    2.758565e+07
# 50%    4.346900e+07
# 75%    7.471030e+07
# max    3.765300e+08

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate values in this data set.

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# There is no null values in this data set.

# %%
df['High'].plot(figsize=(12,4))
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
df['Low'].plot(figsize=(12,4))
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
df['Open'].plot(figsize=(12,4))
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
df['Close'].plot(figsize=(12,4))
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2011 non-null   object
#  1   Open       2011 non-null   float64
#  2   High       2011 non-null   float64
#  3   Low        2011 non-null   float64
#  4   Close      2011 non-null   float64
#  5   Adj Close  2011 non-null   float64
#  6   Volume     2011 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 110.1+ KB

# %%
#Changing date column datatype object to datetime
df['Date']=pd.to_datetime(df['Date'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2011 non-null   datetime64[ns]
#  1   Open       2011 non-null   float64
#  2   High       2011 non-null   float64
#  3   Low        2011 non-null   float64
#  4   Close      2011 non-null   float64
#  5   Adj Close  2011 non-null   float64
#  6   Volume     2011 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 110.1 KB

# %%
#Setting date column as index column
df_1=df.set_index('Date')

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2011 entries, 2012-01-03 to 2019-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2011 non-null   float64
#  1   High       2011 non-null   float64
#  2   Low        2011 non-null   float64
#  3   Close      2011 non-null   float64
#  4   Adj Close  2011 non-null   float64
#  5   Volume     2011 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 110.0 KB

# %%
df_1
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...                ...         ...         ...         ...         ...
# 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#               Volume
# Date
# 2012-01-03  75555200
# 2012-01-04  65005500
# 2012-01-05  67817400
# ...

# %%
df_1['Open'].hist()
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0., 100., 200., 300., 400., 500.]),
#  <a list of 6 Text major ticklabel objects>)

# %%
df_1['Close'].hist()
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350., 400., 450.]),
#  <a list of 10 Text major ticklabel objects>)

# %%
df_1['High'].hist()
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350., 400., 450.]),
#  <a list of 10 Text major ticklabel objects>)

# %%
df_1['Low'].hist()
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350., 400., 450.]),
#  <a list of 10 Text major ticklabel objects>)

# %%
plt.boxplot(df_1['High'])
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
plt.boxplot(df_1['Low'])
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
plt.boxplot(df_1['Open'])
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
plt.boxplot(df_1['Close'])
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
plt.boxplot(df_1['Volume'])
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([-5.0e+07,  0.0e+00,  5.0e+07,  1.0e+08,  1.5e+08,  2.0e+08,
#          2.5e+08,  3.0e+08,  3.5e+08,  4.0e+08]),
#  <a list of 10 Text major ticklabel objects>)

# %%
import calendar
import matplotlib.style as style
import missingno as msno
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
style.use('ggplot')

# %%
print(f"Data Available from {df.Date.min()} to {df.Date.max()}")
#Data Available from 2012-01-03 00:00:00 to 2019-12-30 00:00:00
idx = pd.date_range(df.Date.min(), df.Date.max())
print(f"Days present {len(df)} out of {len(idx)}")
#Days present 2011 out of 2919
# Out:
# Data Available from 2012-01-03 00:00:00 to 2019-12-30 00:00:00
# Days present 2011 out of 2919

# %%
pd.DataFrame(data=idx.difference(df.Date), columns=['Dates'])
# Out:
#          Dates
# 0   2012-01-07
# 1   2012-01-08
# 2   2012-01-14
# 3   2012-01-15
# 4   2012-01-16
# ..         ...
# 903 2019-12-21
# 904 2019-12-22
# 905 2019-12-25
# 906 2019-12-28
# 907 2019-12-29
#
# [908 rows x 1 columns]

# %%
#Calculate return
df_1['return']=(df_1['Close']-df_1['Open'])/df_1['Open']

# %%
ax1=df_1['Close'].plot(style=['-'])
plt.title('Price')
ax1.legend()
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
plt.plot()
# Out:
# []

# %%
#plot all at once
df_1.plot(subplots=True,figsize=(10,12))
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
plt.plot()
# Out:
# []

# %%
ax1=df_1['return'].plot(style=['-'])
plt.title('return')
ax1.legend()
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
plt.plot()
# Out:
# []

# %%
df_1['Close'].diff(1)
# Out:
# Date
# 2012-01-03         NaN
# 2012-01-04    0.315716
# 2012-01-05    0.655712
# 2012-01-06    0.624286
# 2012-01-09   -0.095714
#                 ...
# 2019-12-23    4.559998
# 2019-12-24    0.269989
# 2019-12-26    5.640015
# 2019-12-27   -0.110016
# 2019-12-30    1.720001
# Name: Close, Length: 2011, dtype: float64

# %%
plt.plot(df_1['Close'].diff(1))
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([-20., -15., -10.,  -5.,   0.,   5.,  10.,  15.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
df_1['return'].hist()
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
#Resampling:It is used  to change the frequency of the time series data.For example,you can use this change the daily data into monthly data
#resample daily to weekly data
weekly=df_1.Close.resample('W').mean()

# %%
weekly
# Out:
# Date
# 2012-01-08     59.467858
# 2012-01-15     60.249142
# 2012-01-22     60.780715
# 2012-01-29     62.468285
# 2012-02-05     65.156570
#                  ...
# 2019-12-08    264.327997
# 2019-12-15    270.556000
# 2019-12-22    279.893994
# 2019-12-29    286.994995
# 2020-01-05    291.519989
# Freq: W-SUN, Name: Close, Length: 418, dtype: float64

# %%
# %matplotlib inline
df_1.Close.resample('W').mean().plot(figsize=(12,5))
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
monthly=df_1.Close.resample('M').mean()

# %%
monthly
# Out:
# Date
# 2012-01-31     61.225428
# 2012-02-29     71.081572
# 2012-03-31     82.501104
# 2012-04-30     86.571857
# 2012-05-31     80.667597
#                  ...
# 2019-08-31    204.957728
# 2019-09-30    217.994999
# 2019-10-31    235.286521
# 2019-11-30    262.520503
# 2019-12-31    275.669496
# Freq: M, Name: Close, Length: 96, dtype: float64

# %%
# %matplotlib inline
df_1.Close.resample('M').mean().plot(figsize=(12,5))
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
quarterly=df_1.Close.resample('M').mean()
quarterly
# Out:
# Date
# 2012-01-31     61.225428
# 2012-02-29     71.081572
# 2012-03-31     82.501104
# 2012-04-30     86.571857
# 2012-05-31     80.667597
#                  ...
# 2019-08-31    204.957728
# 2019-09-30    217.994999
# 2019-10-31    235.286521
# 2019-11-30    262.520503
# 2019-12-31    275.669496
# Freq: M, Name: Close, Length: 96, dtype: float64

# %%
# %matplotlib inline
df_1.Close.resample('Q').mean().plot(figsize=(12,5))
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([ 50.,  75., 100., 125., 150., 175., 200., 225., 250., 275.]),
#  <a list of 10 Text major ticklabel objects>)

# %%
yearly=df_1.Close.resample('Y').mean()
yearly
# Out:
# Date
# 2012-12-31     82.292817
# 2013-12-31     67.519269
# 2014-12-31     92.264654
# 2015-12-31    120.040000
# 2016-12-31    104.604008
# 2017-12-31    150.551075
# 2018-12-31    189.053427
# 2019-12-31    207.915737
# Freq: A-DEC, Name: Close, dtype: float64

# %%
# %matplotlib inline
df_1.Close.resample('Y').mean().plot(figsize=(12,5))
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([ 60.,  80., 100., 120., 140., 160., 180., 200., 220.]),
#  <a list of 9 Text major ticklabel objects>)

# %%
col_names = df_1.columns

fig = plt.figure(figsize=(24, 24))
for i in range(6):
  ax = fig.add_subplot(6,1,i+1)
  ax.plot(df_1.iloc[:,i],label=col_names[i])
  df_1.iloc[:,i].rolling(100).mean().plot(label='Rolling Mean')
  ax.set_title(col_names[i],fontsize=18)
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')
  ax.patch.set_edgecolor('black')  
  plt.style.context('fivethirtyeight')
  plt.legend(prop={'size': 8})
  plt.style.use('fivethirtyeight')

fig.tight_layout(pad=3.0)

plt.show()

# %%
##HeatMap to Verify Multicollinearity between Features
fig = plt.figure(figsize=(16,12))
matrix = np.triu(df_1.corr())
ax = sns.heatmap(df_1.corr(),annot=True,annot_kws={"size":14},mask=matrix,cmap='coolwarm')
ax.tick_params(labelsize=14)
sns.set(font_scale=3)
ax.set_title('HeatMap')
plt.style.use('fivethirtyeight')
plt.show()

# %%
from statsmodels.graphics.gofplots import qqplot as qq

# %%
qq_plot = qq(df_1['Close'],line='s')
plt.title('QQ Plot Apple Stock Price')
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=45,fontsize=10)
# Out:
# (array([-200.,    0.,  200.,  400.]),
#  <a list of 4 Text major ticklabel objects>)

# %% [markdown]
# 1.Heavy tailed Distribution-Curve at Extremities
#
# 2.Shows extent of both right and left skews
#
# 3.Shows Distribution is not following gaussian normal distribution

# %%
data_feature_selected = df_1.drop(axis=1,labels=['Open','High','Low','Adj Close','Volume','return'])

# %%
data_feature_selected
# Out:
#                  Close
# Date
# 2012-01-03   58.747143
# 2012-01-04   59.062859
# 2012-01-05   59.718571
# 2012-01-06   60.342857
# 2012-01-09   60.247143
# ...                ...
# 2019-12-23  284.000000
# 2019-12-24  284.269989
# 2019-12-26  289.910004
# 2019-12-27  289.799988
# 2019-12-30  291.519989
#
# [2011 rows x 1 columns]

# %%
col_order = ['Close']
data_feature_selected = data_feature_selected.reindex(columns=col_order)
data_feature_selected
# Out:
#                  Close
# Date
# 2012-01-03   58.747143
# 2012-01-04   59.062859
# 2012-01-05   59.718571
# 2012-01-06   60.342857
# 2012-01-09   60.247143
# ...                ...
# 2019-12-23  284.000000
# 2019-12-24  284.269989
# 2019-12-26  289.910004
# 2019-12-27  289.799988
# 2019-12-30  291.519989
#
# [2011 rows x 1 columns]

# %%
monthly_mean = data_feature_selected['Close'].resample('M').mean()

# %%
monthly_data = monthly_mean.to_frame()
monthly_data
# Out:
#                  Close
# Date
# 2012-01-31   61.225428
# 2012-02-29   71.081572
# 2012-03-31   82.501104
# 2012-04-30   86.571857
# 2012-05-31   80.667597
# ...                ...
# 2019-08-31  204.957728
# 2019-09-30  217.994999
# 2019-10-31  235.286521
# 2019-11-30  262.520503
# 2019-12-31  275.669496
#
# [96 rows x 1 columns]

# %%
monthly_data['Year'] = monthly_data.index.year
monthly_data['Month'] = monthly_data.index.strftime('%B')
monthly_data['dayofweek'] = monthly_data.index.strftime('%A')
monthly_data['quarter'] = monthly_data.index.quarter
monthly_data
# Out:
#                  Close  Year      Month  dayofweek  quarter
# Date
# 2012-01-31   61.225428  2012    January    Tuesday        1
# 2012-02-29   71.081572  2012   February  Wednesday        1
# 2012-03-31   82.501104  2012      March   Saturday        1
# 2012-04-30   86.571857  2012      April     Monday        2
# 2012-05-31   80.667597  2012        May   Thursday        2
# ...                ...   ...        ...        ...      ...
# 2019-08-31  204.957728  2019     August   Saturday        3
# 2019-09-30  217.994999  2019  September     Monday        3
# 2019-10-31  235.286521  2019    October   Thursday        4
# 2019-11-30  262.520503  2019   November   Saturday        4
# 2019-12-31  275.669496  2019   December    Tuesday        4
#
# [96 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(12,10))
palette = sns.color_palette("mako_r", 4)
a = sns.barplot(x="Year", y="Close",hue = 'Month',data=monthly_data)
a.set_title("Stock Prices Year & Month Wise",fontsize=15)
plt.legend(loc='upper left',fontsize=9)
ax.tick_params(axis='x',labelsize=11)
ax.tick_params(axis='y',labelsize=11)
plt.show()

# %%
fig = plt.figure(figsize=(10,16))
fig.set_size_inches(10,16)
group_cols = monthly_data.columns

for enum,i in enumerate(group_cols[1:]):
  ax = fig.add_subplot(4,1,enum+1)
  Aggregated = pd.DataFrame(monthly_data.groupby(str(i))["Close"].mean()).reset_index().sort_values('Close')
  sns.barplot(data=Aggregated,x=str(i),y="Close",ax=ax)
  ax.set(xlabel=str(i), ylabel='Mean Close')
  ax.set_title("Average Stock Price By {}".format(str(i)),fontsize=15)
  plt.xticks(rotation=45,fontsize=10)
  plt.yticks(rotation=45,fontsize=10)
plt.tight_layout(pad=1)

# %%
import altair as alt

# %%
#collapse-hide
alt.Chart(monthly_data).mark_line(point=True).encode(
    x='quarter', 
    y='Close',
    column='Year',
    tooltip=['Year', 'Close']).properties(
    title="Sales: Yearly Subseries plot",
    width=100).configure_header(
    titleColor='black',
    titleFontSize=14,
    labelColor='blue',
    labelFontSize=14
)
# Out:
# alt.Chart(...)

# %%
#box plot to see distribution of sales in each year
fig, ax = plt.subplots(figsize = (12,8))
sns.boxplot(data=monthly_data, x=monthly_data.index.year, y = 'Close',  ax = ax, boxprops=dict(alpha=.3));
sns.swarmplot(data=monthly_data, x=monthly_data.index.year, y = 'Close');
ax.tick_params(axis='x',labelsize=10)
ax.tick_params(axis='y',labelsize=10)

# %%
alt.Chart(monthly_data).mark_line(point=True).encode(
    x='Year', 
    y='Close',
    column='quarter',
    tooltip=['Year', 'Close']).properties(
    title="Sales: Quarterly Subseries plot",
    width=100).configure_header(
    titleColor='black',
    titleFontSize=14,
    labelColor='blue',
    labelFontSize=14
)
# Out:
# alt.Chart(...)

# %%
#collapse-hide
#As stacked bar chart, in % values. 
stack1= alt.Chart(monthly_data[:'2019'].reset_index()).mark_bar().encode(
    x=alt.X('sum(Close)'),
    y='Year:N',
    color=alt.Color(
        'quarter(Date)',
        scale=alt.Scale(scheme='category10')),
    tooltip=["Date", "Close"]).properties(
    height=100, 
    width = 300,
    title = "Sum of Close price by each Quarter")
    
stack2= alt.Chart(monthly_data[:'2019'].reset_index()).mark_bar().encode(
    x=alt.X('sum(Close)', stack='normalize'),
    y='Year:N',
    color=alt.Color(
        'quarter(Date)', 
        scale=alt.Scale(scheme='category10')),
    tooltip=["Date", "Close"]
    ).properties(
    height=100, 
    width = 300, 
    title = "Sum of Close as % by each Quarter")



stack1 | stack2
# Out:
# alt.HConcatChart(...)

# %%
pie= monthly_data[:'2019'].groupby(monthly_data[:'2019'].index.quarter)["Close"].sum().plot.bar(
    title="Total Close price by Quarter 2012-2019",fontsize=10)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose as sd
from pylab import rcParams

# %%
rcParams['figure.figsize'] = 18, 8
plt.figure(figsize=(12,16))
decomposed_series = sd(monthly_data['Close'])
decomposed_series.plot()
plt.show()

# %%
##Drilling Down and Observing Seasonality
decomposed_series.seasonal['2012':'2013'].plot()
fig = plt.figure(figsize=(8,8))

# %%
from statsmodels.tsa.stattools import adfuller

# %%
##ADF Test-Statsmodels Library

def ad_fuller_func(X):
  result_ad_fuller = adfuller(X)
  print('ADF Statistic: %f' % result_ad_fuller[0])
  print('p-value: %f' %result_ad_fuller[1])
  print('Critical Values:')
  for key, value in result_ad_fuller[4].items():
	  print('\t%s: %.3f' % (key, value))
 
  if result_ad_fuller[0] < result_ad_fuller[4]['5%']:
    print('Reject Null Hypothesis(Ho)-Time Series is Stationary')
  else:
    print('Failed to Reject Ho-Time Series is Non-Stationary')

# %%
ad_fuller_func(monthly_data['Close'])
# Out:
# ADF Statistic: 0.512110
# p-value: 0.985237
# Critical Values:
# 	1%: -3.502
# 	5%: -2.893
# 	10%: -2.583
# Failed to Reject Ho-Time Series is Non-Stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig,(ax1,ax2) = plt.subplots(2,figsize=(12,12))
acf = plot_acf(monthly_data['Close'],lags=90,ax=ax1)
ax1.set_title('AutoCorrelation Long Term')
acf = plot_acf(monthly_data['Close'],lags=30,ax=ax2)
ax2.set_title('AutoCorrelation Short Term')
ax1.set_ylabel('Correlation')
ax1.set_xlabel('Lags')
ax2.set_ylabel('Correlation')
ax2.set_xlabel('Lags')
# Out:
# Text(0.5, 0, 'Lags')
